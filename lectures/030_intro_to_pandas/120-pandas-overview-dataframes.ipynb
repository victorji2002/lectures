# %%
# %reload_ext postcell
# %postcell register
# Out:
# PostCell loaded
# Loading config file from /Users/victorji/Documents/GitHub/lectures/postcell.conf
# Registered user Victor_Ji at https://postcell.io/post_cell

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pandas - dataframes

# %% [markdown]
# Pandas dataframes are the main tool used by data scientists to explore data.Generally, "pandas" is a synonym for pandas dataframes. Pandas is deigned to work with what we normally think of as "business data."
#
# Given what we have learned so far, we can think of dataframes as: Numpy with labels and a set of series objects.
#
# #### Numpy with labels

# %%
rand_array = (np.random.rand(10,3) * 100).round()
rand_array
# Out:
# array([[93., 60., 50.],
#        [11., 34., 98.],
#        [17., 33., 16.],
#        [74., 10., 20.],
#        [ 2., 33.,  5.],
#        [28., 32., 53.],
#        [95., 69., 37.],
#        [62., 58., 63.],
#        [21., 55., 91.],
#        [64., 53., 75.]])

# %% [markdown]
# With pandas, we can annotate this numeric matrix with labels:

# %%
student_scores_pd = pd.DataFrame(rand_array
             , columns=['Assignment 1', 'Assignment 2', 'Test']
             , index=['Homer', 'Marge', 'Bart', 'Lisa', 'Maggie', 'Jon', 'Arya', 'Ned', 'Danny', 'That red lady']
            )
student_scores_pd
# Out:
#                Assignment 1  Assignment 2  Test
# Homer                  93.0          60.0  50.0
# Marge                  11.0          34.0  98.0
# Bart                   17.0          33.0  16.0
# Lisa                   74.0          10.0  20.0
# Maggie                  2.0          33.0   5.0
# Jon                    28.0          32.0  53.0
# Arya                   95.0          69.0  37.0
# Ned                    62.0          58.0  63.0
# Danny                  21.0          55.0  91.0
# That red lady          64.0          53.0  75.0

# %% [markdown]
# A dataframe can be converted back to a numpy:

# %%
student_scores_pd.values
# Out:
# array([[93., 60., 50.],
#        [11., 34., 98.],
#        [17., 33., 16.],
#        [74., 10., 20.],
#        [ 2., 33.,  5.],
#        [28., 32., 53.],
#        [95., 69., 37.],
#        [62., 58., 63.],
#        [21., 55., 91.],
#        [64., 53., 75.]])

# %%
student_scores_pd.to_numpy()
# Out:
# array([[93., 60., 50.],
#        [11., 34., 98.],
#        [17., 33., 16.],
#        [74., 10., 20.],
#        [ 2., 33.,  5.],
#        [28., 32., 53.],
#        [95., 69., 37.],
#        [62., 58., 63.],
#        [21., 55., 91.],
#        [64., 53., 75.]])

# %% [markdown]
# #### Set of series objects
#
# ![](images/dataframes.jpg)

# %%
homers_grades = pd.Series(np.round(100 * np.random.rand(3)))
marges_grades = pd.Series(np.round(100 * np.random.rand(3)))
barts_grades = pd.Series(np.round(100 * np.random.rand(3)))
lisas_grades = pd.Series(np.round(100 * np.random.rand(3)))
maggies_grades = pd.Series(np.round(100 * np.random.rand(3)))
jons_grades = pd.Series(np.round(100 * np.random.rand(3)))
aryas_grades = pd.Series(np.round(100 * np.random.rand(3)))
neds_grades = pd.Series(np.round(100 * np.random.rand(3)))
dannys_grades = pd.Series(np.round(100 * np.random.rand(3)))
thatredlady_grades = pd.Series(np.round(100 * np.random.rand(3)))

# %%
homers_grades
# Out:
# 0    53.0
# 1    48.0
# 2    58.0
# dtype: float64

# %%
student_scores_pd = pd.DataFrame({
    'homer': homers_grades
    , 'marge': marges_grades
    , 'bart': barts_grades
    , 'lisa': lisas_grades
    , 'maggie': maggies_grades
    , 'jon': jons_grades
    , 'arya': aryas_grades
    , 'ned': neds_grades
    , 'danny': dannys_grades
    , 'That red lady': thatredlady_grades
})
student_scores_pd
# Out:
#    homer  marge  bart  lisa  maggie   jon  arya    ned  danny  That red lady
# 0   53.0   75.0  16.0  12.0    64.0   9.0  70.0   64.0   10.0           96.0
# 1   48.0   30.0   1.0  15.0    94.0  46.0  19.0  100.0   21.0           20.0
# 2   58.0   90.0   3.0  33.0    69.0  86.0  42.0   52.0   33.0           31.0

# %%
student_scores_pd = student_scores_pd.set_index(pd.Index(['Assignment 1', 'Assignment 2', 'Test']))
student_scores_pd
# Out:
#               homer  marge  bart  lisa  maggie   jon  arya    ned  danny  \
# Assignment 1   53.0   75.0  16.0  12.0    64.0   9.0  70.0   64.0   10.0
# Assignment 2   48.0   30.0   1.0  15.0    94.0  46.0  19.0  100.0   21.0
# Test           58.0   90.0   3.0  33.0    69.0  86.0  42.0   52.0   33.0
#
#               That red lady
# Assignment 1           96.0
# Assignment 2           20.0
# Test                   31.0

# %%
#student_scores_pd = student_scores_pd.set_index([['Assignment 1', 'Assignment 2', 'Test']])
#student_scores_pd

# %%
student_scores_pd = student_scores_pd.T
student_scores_pd
# Out:
#                Assignment 1  Assignment 2  Test
# homer                  53.0          48.0  58.0
# marge                  75.0          30.0  90.0
# bart                   16.0           1.0   3.0
# lisa                   12.0          15.0  33.0
# maggie                 64.0          94.0  69.0
# jon                     9.0          46.0  86.0
# arya                   70.0          19.0  42.0
# ned                    64.0         100.0  52.0
# danny                  10.0          21.0  33.0
# That red lady          96.0          20.0  31.0

# %% [markdown]
# Notice that while each series has its own index, in a dataframe, the index is shared among all columns.

# %%
student_scores_pd['Test']
# Out:
# homer            58.0
# marge            90.0
# bart              3.0
# lisa             33.0
# maggie           69.0
# jon              86.0
# arya             42.0
# ned              52.0
# danny            33.0
# That red lady    31.0
# Name: Test, dtype: float64

# %%
type(student_scores_pd['Test'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Creating dataframes

# %% [markdown]
# Above we saw two examples of creating dataframes from dictionaries and numpy arrays. You are more likely to create dataframes by reading them from a data file or loading them from an sql server. The pandas overview already showed such an example but let's take a closer look at some important functions.

# %% [markdown]
# #### `.read_csv()`
#
# Pandas provides a very useful way of ingesting csv (command delimited) files. These types of files are overwhelmingly the format used to distribute small and medium sized data.

# %%
data_df = pd.read_csv('../../datasets/deaths-in-gameofthrones/game-of-thrones-deaths-data.csv')

# %%
data_df.head()
# Out:
#    order  season  episode character_killed        killer          method  \
# 0      1       1        1     Waymar Royce  White Walker       Ice sword
# 1      2       1        1            Gared  White Walker       Ice sword
# 2      3       1        1             Will     Ned Stark     Sword (Ice)
# 3      4       1        1             Stag      Direwolf  Direwolf teeth
# 4      5       1        1         Direwolf          Stag          Antler
#
#   method_cat                       reason         location  \
# 0      Blade                      Unknown  Beyond the Wall
# 1      Blade                      Unknown  Beyond the Wall
# 2      Blade  Deserting the Night’s Watch       Winterfell
# 3     Animal                      Unknown       Winterfell
# 4     Animal                      Unknown       Winterfell
#
#                    allegiance  importance
# 0  House Royce, Night’s Watch         2.0
# 1               Night’s Watch         2.0
# 2               Night’s Watch         2.0
# 3                         NaN         1.0
# 4                         NaN         1.0

# %% [markdown]
# Note that you can load a file directly from the web:

# %%
# %%time
pd.read_csv('https://raw.githubusercontent.com/washingtonpost/data-game-of-thrones-deaths/master/game-of-thrones-deaths-data.csv').head()
# Out:
# CPU times: user 7.84 ms, sys: 2.6 ms, total: 10.4 ms
# Wall time: 85 ms
#    order  season  episode character_killed        killer          method  \
# 0      1       1        1     Waymar Royce  White Walker       Ice sword
# 1      2       1        1            Gared  White Walker       Ice sword
# 2      3       1        1             Will     Ned Stark     Sword (Ice)
# 3      4       1        1             Stag      Direwolf  Direwolf teeth
# 4      5       1        1         Direwolf          Stag          Antler
#
#   method_cat                       reason         location  \
# 0      Blade                      Unknown  Beyond the Wall
# 1      Blade                      Unknown  Beyond the Wall
# 2      Blade  Deserting the Night’s Watch       Winterfell
# 3     Animal                      Unknown       Winterfell
# 4     Animal                      Unknown       Winterfell
#
#                    allegiance  importance
# 0  House Royce, Night’s Watch         2.0
# 1               Night’s Watch         2.0
# 2               Night’s Watch         2.0
# 3                         NaN         1.0
# 4                         NaN         1.0

# %%
#pd.read_excel()

# %% [markdown]
# The `.read_csv` function is very rich and lets you control:
# 1. Column names, including working with datasets which do not include column names: `names`, `header`
# 2. Which delimiter to use: comma, tabs, etc.: `delimiter`
# 3. Custom data types (in case your integers are being brought in as strings or floats): `dtype`
#     a. `parse_dates` lets you control which columns are date or time values
#
# etc.

# %% [markdown]
# Similarly `.read_sql` lets you read resutls of sql queries, `.read_feather` lets you read a very important upcoming format called `feather` or `arrow`. Popular format 'parquet' from the Hadoop ecosystem can be read with `.read_parquet`

# %% [markdown]
# An example of read_csv's richness:
#
# `.read_csv(header=int or list of int)`
# The option of `header` can be used to control the header.
#     - `header = 0` The first row contains the header, use that for column names
#     - `header = [0,1,2,3,10]` Only import columns 0, 1, 2, 3 and 10 (skip 4-9)
#     - `header = None` No column names provided

# %% [markdown]
# #### `.read_html()`

# %% [markdown]
# The `read_html` function parses a web page to extract tables. This functionality is built on top of the "beautiful soup" library. Using that library is not necessarily easy for new developers. Along with Python, they also have to know a bit about the html markup langauge. Pandas makes such tasks trivial.

# %%
import ssl
#In some instances, students get ssl errors, this will resolve it
#https://stackoverflow.com/a/56230607
ssl._create_default_https_context = ssl._create_unverified_context
# Out:
#   Cell In[25], line 3
#     https://stackoverflow.com/a/56230607
#           ^
# SyntaxError: invalid syntax

# %%
# %%time
html_tables = pd.read_html('https://en.wikipedia.org/wiki/World_population')
# Out:
# CPU times: user 3.56 ms, sys: 2.18 ms, total: 5.74 ms
# Wall time: 153 ms
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "html_tables = pd.read_html('https://en.wikipedia.org/wiki/World_population')\n")
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/IPython/core/magics/execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/IPython/core/magics/execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:1
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)    979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)    247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/html.py:806, in _LxmlFrameParser._build_doc(self)
#     804             pass
#     805     else:
# --> 806         raise e
#     807 else:
#     808     if not hasattr(r, "text_content"):
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/html.py:785, in _LxmlFrameParser._build_doc(self)
#     783 try:
#     784     if is_url(self.io):
# --> 785         with get_handle(
#     786             self.io, "r", storage_options=self.storage_options
#     787         ) as f:
#     788             r = parse(f.handle, parser=parser)
#     789     else:
#     790         # try to parse the input in the simplest way
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File /opt/anaconda3/envs/finm/lib/python3.13/site-packages/pandas/io/common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File /opt/anaconda3/envs/finm/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
len(html_tables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 len(html_tables)
#
# NameError: name 'html_tables' is not defined

# %%
html_tables[0]

# %%
html_tables[1]

# %% [markdown]
# If you want a specific table, use the `match` keyword to search for a specific table header

# %%
pd.read_html('https://en.wikipedia.org/wiki/World_population'
             , match='10 most densely populated countries')[0]

# %% [markdown]
# **Exercise** Download the following file to you computer and read it into a dataframe: https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv
#
# Note, you must download the file to you computer, you may not use Pandas to read directly from the web.

# %%
# %%postcell exercise_030_120_a
#
# #type your answer here

# %% [markdown]
# ### Getting rows and columns from Dataframes

# %%
student_scores_pd

# %% [markdown]
# Similar to series, values in dataframes can be retrieved in several ways:
# 1. Implicit index (similar to lists)
# 2. Explicit index or label (similar to dictionaries)
# 3. Slicing
# 4. Boolean masking
# 5. Fancy indexing

# %% [markdown]
# #### Implicit index

# %% [markdown]
# Perhaps surprisingly, implicit index is not commonly used to acces rows or columns (see `iloc` or `icol`)

# %%
student_scores_pd

# %%
student_scores_pd[0]

# %%
student_scores_pd.iloc[:, 0]

# %% [markdown]
# #### Explicit index or labels

# %%
student_scores_pd

# %% [markdown]
# In a dataframe, using an explicit key returns the column associated with that key. Note that this is not what you may have expected. According to the rule "first rows, then column" we learned in numpy, the syntax in the following line should result a row, but Pandas makes an exception here.

# %%
student_scores_pd['homer']

# %%
student_scores_pd['Test']

# %% [markdown]
# Notice, in the last example, although, in common vernacular, you are asking for a column of data. It is more precise to say that you are asking for a series, since a series contains a column of values, and the index associated with it.

# %% [markdown]
# Using `.loc` brings back the "rows then column" scheme.

# %%
student_scores_pd.loc['homer']

# %%
student_scores_pd.loc[:, 'Test']

# %%
student_scores_pd.loc['homer', "Test"]

# %% [markdown]
# Once you have a series, you can operate on it using the same methods we learned in the previous lecture

# %%
tests_s = student_scores_pd['Test']

# %%
type(tests_s)

# %%
tests_s

# %%
tests_s['homer'] # <= this is a series, not a dataframe

# %% [markdown]
# Dataframe and series operations are often combined

# %%
student_scores_pd['Test']['homer']

# %% [markdown]
# In the pervious example, `student_scores_pd['Test']...` returns a series, the subsequent `...['homer']` then pulls out Homer's test results.

# %% [markdown]
# **Exercise** Find the average of all test scores in `student_scores_pd`

# %%
# %%postcell exercise_030_120_b
#
# #type your answer here

# %% [markdown]
# #### Fancy indexing

# %% [markdown]
# Fnacy indexing operates on columns

# %%
student_scores_pd

# %%
student_scores_pd[['Test', 'Test', 'Assignment 1']]

# %% [markdown]
# **Exercise** Get the `Test` series from `student_scores_pd`

# %%
# %%postcell exercise_030_120_c
#
# #type your answer here

# %% [markdown]
# #### Slicing

# %% [markdown]
# However, if slicing syntax is used to operate on rows

# %%
student_scores_pd

# %%
student_scores_pd['bart': 'arya']

# %% [markdown]
# **Note** Sclicing columns names will not work (unless the `.loc` notation is used)

# %%
student_scores_pd['Assignment 1': 'Assignment 2']

# %%
student_scores_pd.loc[:, 'Assignment 1': 'Assignment 2']

# %% [markdown]
# **Exrercise** Use slicing to find test scores (not assignments) for Maggie, Jon and Arya (note that all three are next to each ohter in the dataframe

# %%
# %%postcell exercise_030_120_d
#
# #type your answer here

# %% [markdown]
# #### Masking

# %% [markdown]
# Masking syntax also operates on rows

# %%
student_scores_pd

# %%
student_scores_pd[student_scores_pd.Test > 50]

# %%
student_scores_pd.Test > 50

# %%
student_scores_pd[student_scores_pd.index == 'homer']

# %% [markdown]
# **Exercise** Find all records where test scores are above 80 in dataframe `student_scores_pd`

# %%
# %%postcell exercise_030_120_e
#
# #type your answer here
# scores_above_80 = student_scores_pd[student_scores_pd.Test > 80]
# print(scores_above_80)
# Out:
# Cell posted for evaluation
#        Assignment 1  Assignment 2  Test
# marge          75.0          30.0  90.0
# jon             9.0          46.0  86.0

# %% [markdown]
# **Exercise** Find all records where test scores are above 80 or assignment 1 scores are above 75 in dataframe `student_scores_pd`

# %%
# %%postcell exercise_030_120_h
#
# #type your answer here
# scores_80_or_75 = student_scores_pd[(student_scores_pd.Test > 80) | (student_scores_pd['Assignment 1'] > 75)]
# print(scores_80_or_75)
# Out:
# Cell posted for evaluation
#                Assignment 1  Assignment 2  Test
# marge                  75.0          30.0  90.0
# jon                     9.0          46.0  86.0
# That red lady          96.0          20.0  31.0

# %% [markdown]
# ### `.loc`, `.iloc` and `.at`

# %% [markdown]
# Just like `Series`, `Dataframe` objects also use:
#
# - `df.loc[]` to operate only on explicit keys/labels (like dictonaries)
# - `df.iloc[]` to operate only on implicit index locations (like lists)
# - `df.at[]` to return a single item

# %% [markdown]
# However, since Dataframes are a multidimensional data structure, these functions provide direct ability to access rows and columns
#
# `df.loc/iloc/at[rows, columns]`

# %%
student_scores_pd
# Out:
#                Assignment 1  Assignment 2  Test
# homer                  53.0          48.0  58.0
# marge                  75.0          30.0  90.0
# bart                   16.0           1.0   3.0
# lisa                   12.0          15.0  33.0
# maggie                 64.0          94.0  69.0
# jon                     9.0          46.0  86.0
# arya                   70.0          19.0  42.0
# ned                    64.0         100.0  52.0
# danny                  10.0          21.0  33.0
# That red lady          96.0          20.0  31.0

# %% [markdown]
# ### `.loc` key based indexing

# %% [markdown]
# Get the column 'Test' and all rows

# %%
student_scores_pd.loc[:,'Test']
# Out:
# homer            58.0
# marge            90.0
# bart              3.0
# lisa             33.0
# maggie           69.0
# jon              86.0
# arya             42.0
# ned              52.0
# danny            33.0
# That red lady    31.0
# Name: Test, dtype: float64

# %% [markdown]
# Get all columns for row containing 'homer'

# %%
student_scores_pd.loc['homer', :]
# Out:
# Assignment 1    53.0
# Assignment 2    48.0
# Test            58.0
# Name: homer, dtype: float64

# %% [markdown]
# Get the column 'Test' and row with index 'homer'

# %%
student_scores_pd.loc['homer', 'Test']
# Out:
# np.float64(58.0)

# %% [markdown]
# Get columns 'Assignment 1' and 'Assignment 2' and rows containing Simpson children (**fancy indexing**)

# %%
student_scores_pd.loc[['bart', 'lisa', 'maggie'],['Assignment 1', 'Assignment 2']]

# %% [markdown]
# Get 'Test' scores for everyone between 'bart' and 'maggie' (**slicing** and **fancy indexing**)

# %%
student_scores_pd.loc['bart':'maggie', ['Assignment 1', 'Assignment 2']]
# Out:
#         Assignment 1  Assignment 2
# bart            16.0           1.0
# lisa            12.0          15.0
# maggie          64.0          94.0

# %% [markdown]
# **Exercise** Find Maggie and Danny's 'Assignment 1' score

# %%
# %%postcell exercise_030_120_f
#
# #type your answer here

# %% [markdown]
# ### .iloc location based indexing

# %%
student_scores_pd

# %% [markdown]
# Get the first column and all rows

# %%
student_scores_pd.iloc[:, 0]

# %% [markdown]
# Get the second column and 3-5 rows

# %%
student_scores_pd.iloc[3:6, 1]

# %% [markdown]
# **Exercise** Get the first three rows of `student_scores_pd`, but only include 'Assignment 1' and 'Assignment 2'

# %%
# %%postcell exercise_030_120_g
#
# #type your answer here

# %% [markdown]
# ### `.at` return a single value

# %% [markdown]
# Get Homer's test results (think of it as `.loc` which returns a single value...or an error)

# %%
student_scores_pd.at['homer', 'Test']

# %%
student_scores_pd.at['homer',['Test', 'Assignment 1']]

# %% [markdown]
# #### `.query()`
#
# Although I personally haven't developed a habit of using this function, `df.query(..)` can be very useful and intuitive

# %%
student_scores_pd

# %%
student_scores_pd.query('Test > 50')

# %% [markdown]
# The above example is the same as:

# %%
student_scores_pd[student_scores_pd['Test'] > 50]

# %% [markdown]
# As you can see, `.query()` is much simpler
